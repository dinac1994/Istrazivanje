# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline 
sns.set(color_codes=True)

# %% [markdown]
# Tablica koja prikazuje prosječni score svake osobe za svaku vještinu.

# %%
df = pd.read_excel("SEVER_2.xlsx")
df.iloc[:,0] = df.iloc[:,0]/10
df.iloc[:,1] = df.iloc[:,1]/10
df.iloc[:,2] = df.iloc[:,2]/10
df.head(5)
# Out:
#    Vjestina aktivnog slusanja  Vjestina umrezavanja  \
# 0                         4.6                   4.0
# 1                         4.2                   3.6
# 2                         4.8                   4.2
# 3                         4.8                   4.8
# 4                         4.0                   5.0
#
#    Vjestina utjecaja na druge  Muskarac  Zena
# 0                         3.6         0     1
# 1                         5.0         0     1
# 2                         4.4         0     1
# 3                         4.2         0     1
# 4                         4.6         0     1

# %% [markdown]
# Računanje Pearsonovih koeficijanata korelacije između svih atributa.

# %%
plt.figure(figsize=(20,10))
c = df.corr(method = 'pearson')
sns.heatmap(c, annot=True, cmap='viridis')
